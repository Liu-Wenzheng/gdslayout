# %% [markdown]
# ## Optomechanical_mass

# %% [markdown]
# ### Example 1
# - Device: Optomechanical_mass
#
# Check the device

# %%
from gdslayout.structure import Structure

structure = Structure(config_path="./config_example/9.yaml")
component, P = structure._load_device()
component.plot()

# %% [markdown]
# #### Show the device's ports

# %%
from gdslayout.visualization import plot_component
print(component.pprint_ports())
fig, ax = plot_component(component, with_ports=True, with_labels=True, figsize=(10, 8))
# Out:
# ┏━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name    ┃ width ┃ orientation ┃ layer         ┃ center      ┃ port_type ┃
# ┡━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ top     │ 1.0   │ 90.0        │ SLAB150 (2/0) │ (0.0, 80.0) │ optical   │
# │ coupler │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 0.0)  │ optical   │
# └─────────┴───────┴─────────────┴───────────────┴─────────────┴───────────┘
# None

# %% [markdown]
# ### Example 2
# - Device 1: Optomechanical_mass
# - Device 2: PhC_optomechanics1
# - Coupler: point

# %%
structure = Structure(config_path="./config_example/10.yaml")
component = structure.build()
component.plot()
# Out:
# ✅ Connected top -> bottom

# %% [markdown]
# #### Show the component's ports

# %%
from gdslayout.visualization import plot_component
fig, ax = plot_component(component, with_ports=True, with_labels=True, figsize=(10, 8))
print(component.pprint_ports())
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name          ┃ width ┃ orientation ┃ layer         ┃ center       ┃ port_type ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ coupler       │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 0.0)   │ optical   │
# │ in            │ 0.2   │ 180.0       │ SLAB150 (2/0) │ (-10.0, 0.0) │ optical   │
# │ out           │ 0.2   │ 0.0         │ SLAB150 (2/0) │ (10.0, 0.0)  │ optical   │
# │ device_center │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, -78.5) │ optical   │
# └───────────────┴───────┴─────────────┴───────────────┴──────────────┴───────────┘
# None

# %% [markdown]
# Check the device 1

# %%
structure.devices[0].plot()

# %% [markdown]
# Check the device 2

# %%
structure.devices[1].plot()

# %% [markdown]
# Check the device (devices combination)

# %%
structure.device.plot()

# %% [markdown]
# #### Show the device's ports

# %%
from gdslayout.visualization import plot_component
print(structure.device.pprint_ports())
fig, ax = plot_component(structure.device, with_ports=True, with_labels=True, figsize=(10, 8))
# Out:
# ┏━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name    ┃ width ┃ orientation ┃ layer         ┃ center        ┃ port_type ┃
# ┡━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ bottom  │ 1.0   │ 270.0       │ SLAB150 (2/0) │ (0.0, -9.736) │ optical   │
# │ coupler │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 0.0)    │ optical   │
# └─────────┴───────┴─────────────┴───────────────┴───────────────┴───────────┘
# None

# %% [markdown]
# Check the coupler

# %%
structure.coupler.plot()

# %% [markdown]
# ### Example 3
# - Device 1: Optomechanical_mass
# - Device 2: PhC_optomechanics2
# - Coupler: port_coupler

# %%
from gdslayout.structure import Structure
structure = Structure(config_path="./config_example/12.yaml")
component = structure.build()
component.plot()
# Out:
# ✅ Connected top -> bottom

# %% [markdown]
# #### Show the component's ports

# %%
from gdslayout.visualization import plot_component
fig, ax = plot_component(component, with_ports=True, with_labels=True, figsize=(10, 8))
print(component.pprint_ports())
# Out:
# ┏━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name          ┃ width ┃ orientation ┃ layer         ┃ center                                    ┃ port_type ┃
# ┡━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ coupler       │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 1.8121342951089923)                 │ optical   │
# │ in            │ 0.518 │ 180.0       │ SLAB150 (2/0) │ (-58.980000000000004, 1.8121342951089923) │ optical   │
# │ out           │ 0.518 │ 0.0         │ SLAB150 (2/0) │ (194.000096466385, -76.74579861398905)    │ optical   │
# │ device_center │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, -76.746)                            │ optical   │
# └───────────────┴───────┴─────────────┴───────────────┴───────────────────────────────────────────┴───────────┘
# None

# %% [markdown]
# Check the device 1

# %%
structure.devices[0].plot()

# %% [markdown]
# Check the device 2

# %%
structure.devices[1].plot()

# %% [markdown]
# Check the device (devices combination)

# %%
structure.device.plot()

# %% [markdown]
# #### Show the device 1's ports

# %%
from gdslayout.visualization import plot_component
print(structure.devices[1].pprint_ports())
fig, ax = plot_component(structure.devices[1], with_ports=True, with_labels=True, figsize=(10, 8))
# Out:
# ┏━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name    ┃ width ┃ orientation ┃ layer         ┃ center                      ┃ port_type ┃
# ┡━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ top     │ 1.0   │ 90.0        │ SLAB150 (2/0) │ (0.0, 7.788)                │ optical   │
# │ bottom  │ 1.0   │ 270.0       │ SLAB150 (2/0) │ (0.0, -4.28)                │ optical   │
# │ in      │ 1.0   │ 180.0       │ SLAB150 (2/0) │ (-10.0, 1.8121342951089923) │ optical   │
# │ out     │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (10.0, 1.8121342951089923)  │ optical   │
# │ coupler │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 1.8121342951089923)   │ optical   │
# │ exciton │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 0.0)                  │ optical   │
# └─────────┴───────┴─────────────┴───────────────┴─────────────────────────────┴───────────┘
# None

# %% [markdown]
# #### Show the device's ports

# %%
from gdslayout.visualization import plot_component
print(structure.device.pprint_ports())
fig, ax = plot_component(structure.device, with_ports=True, with_labels=True, figsize=(10, 8))
# Out:
# ┏━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ name    ┃ width ┃ orientation ┃ layer         ┃ center                      ┃ port_type ┃
# ┡━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ top     │ 1.0   │ 90.0        │ SLAB150 (2/0) │ (0.0, 7.788)                │ optical   │
# │ bottom  │ 1.0   │ 270.0       │ SLAB150 (2/0) │ (0.0, -4.28)                │ optical   │
# │ in      │ 1.0   │ 180.0       │ SLAB150 (2/0) │ (-10.0, 1.8121342951089923) │ optical   │
# │ out     │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (10.0, 1.8121342951089923)  │ optical   │
# │ coupler │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 1.8121342951089923)   │ optical   │
# │ exciton │ 1.0   │ 0.0         │ SLAB150 (2/0) │ (0.0, 0.0)                  │ optical   │
# └─────────┴───────┴─────────────┴───────────────┴─────────────────────────────┴───────────┘
# None

# %% [markdown]
# Check the coupler

# %%
structure.coupler[0].plot()

# %%
structure.coupler[1].plot()

# %%
structure.create_gds('./gds/12.gds')
# Out:
# './gds/12.gds'
